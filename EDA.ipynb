# %% [markdown]
# # Visualizations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

pd.options.mode.chained_assignment = None
# %matplotlib inline

# %% [markdown]
# ### We called the big dataframe we created in the cleaning part.

# %%
df = pd.read_csv('./all_cars.csv')
df.drop("Unnamed: 0", axis = 1, inplace = True)
df
# Out:
#          price    Year  Hand  Kilometer                Area   Gearbox  \
# 0      28000.0  2014.0   3.0   158000.0    פתח תקוה והסביבה  אוטומטית
# 1      30000.0  2013.0   5.0   117000.0        מושבים בשפלה  אוטומטית
# 2      33000.0  2011.0   3.0   105000.0   נס ציונה - רחובות  אוטומטית
# 3      28000.0  2013.0   2.0   220000.0    פתח תקוה והסביבה  אוטומטית
# 4      21000.0  2010.0   3.0   167000.0    פתח תקוה והסביבה  אוטומטית
# ...        ...     ...   ...        ...                 ...       ...
# 5381   45000.0  2009.0   2.0        2.0     ירושלים והסביבה  אוטומטית
# 5382  180000.0  2021.0   1.0     3000.0        מושבים בצפון  אוטומטית
# 5383   34000.0  2012.0   3.0   190000.0        מושבים במרכז     ידנית
# 5384  150000.0  2017.0   4.0    65000.0    פתח תקוה והסביבה  אוטומטית
# 5385   45000.0  2012.0   2.0    98000.0             תל אביב  אוטומטית
#
#       Engine capcity                    Color manufacturer    type
# 0             1000.0                     שחור       יונדאי     i10
# 1             1400.0                     אפור       יונדאי     i20
# 2             1560.0                     אפור       יונדאי     i25
# 3             1590.0               כחול מטאלי       יונדאי   i30cw
# 4             1600.0                     תכלת       יונדאי   i30cw
# ...              ...                      ...          ...     ...
# 5381          1598.0                     שחור         מיני    קופר
# 5382          1499.0                אפור עכבר         מיני    קופר
# 5383          1598.0                      קרם         מיני     ONE
# 5384          1998.0                     כסוף         מיני     JCW
# 5385          1598.0                     כתום         מיני     ONE
#
# [5386 rows x 10 columns]

# %% [markdown]
# # Information about the car features
#
# * we create line plots to see the influence of some columns:
#     * Year and price - we can see that if the year is bigger the price is bigger.
#     * Hand and price - we can see that if the hand is bigger the price is decreased.
#     * Kilometer and price - We can see that the mileage affects the price but so does the model. That's why the graph looks like this.
#     * Engine capcity and price - We can see that the Engine capcity affects the price but so does the model. That's why the graph looks like this.

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

sns.lineplot(ax=axes[0][0], x= df['Year'], y = df['price'])
axes[0][0].set_title('Year')

sns.lineplot(ax=axes[0][1], x = df['Hand'], y = df['price'])
axes[0][1].set_title('Hand')

sns.lineplot(ax=axes[1][0], x = df['Kilometer'], y = df['price'])
axes[1][0].set_title('Kilometer')

sns.lineplot(ax=axes[1][1], x = df['Engine capcity'], y = df['price'])
axes[1][1].set_title('Engine capcity')
# Out:
# Text(0.5, 1.0, 'Engine capcity')

# %% [markdown]
# #### We created a histogram that shows how many vehicles are in each type of information found in the columns

# %%
def replace_to_numeric(df):
    
    # replce the gearbox types to numric type
    replace_gearbox = {'אוטומטית':1,'ידנית':2,'רובוטית':3,'טיפטרוניק':4,'DSG':5,'סטפטרוניק':6,'dualogic':7} 
    df = df.replace(replace_gearbox)
    
    return df

# %% [markdown]
# * We can see that most of the cars price is between 0-50000.
# * We can see the most of the cars is between the years 2011-2016.
# * We can see the most of the cars is hand 2.
# * We can see the most of the cars kiliomter is between 100K - 200K.
# * We can see that most of the cars have automatic gearbox.
# * We can see that most of the cars have engine capcity of 1500.

# %%
dfCopy = df.copy()
dfCopy = replace_to_numeric(dfCopy)
list_Cars = dfCopy.hist(bins=25, layout=(2,3), figsize=(15,15),column =['price','Year','Hand','Kilometer','Gearbox','Engine capcity'])

# %%
df_avarege = pd.read_csv("./avarege car information.csv")
df_avarege.drop("Unnamed: 0", axis = 1, inplace = True)
df_avarege
# Out:
#    Manufacturer  Avarege price  Avarege kilometer  Avarege year  Avarege hand  \
# 0       hyundai   34478.572650      141324.358974   2012.416667      2.551282
# 1    volkswagen   44932.680191      145564.911695   2011.307876      2.661098
# 2           kia   45208.338583      317958.255906   2015.039370      2.141732
# 3        suzuki   32426.258555      144180.513308   2011.619772      2.258555
# 4      mercedes  176158.375000      173089.541667   2014.199405      2.511905
# 5        toyota   46002.426778      162776.742678   2011.456067      2.246862
# 6         mazda   36248.100559      174432.201117   2009.882682      2.862197
# 7         skoda   67974.838057      141281.795547   2014.587045      2.240891
# 8     chevrolet   40885.723270      127538.503145   2012.477987      2.515723
# 9         honda   35094.686636      176441.829493   2009.543779      2.930876
# 10         seat   56495.115854      124535.231707   2013.750000      2.646341
# 11          bmw  158783.778689      108921.377049   2014.368852      2.688525
# 12      renault   40913.462963      140815.666667   2013.827160      2.265432
# 13      peugeot   42520.569620      117823.101266   2013.341772      2.272152
# 14         ford   38215.147436      159793.807692   2011.878205      2.551282
# 15         audi  122228.775641      123578.474359   2013.858974      2.858974
# 16       subaru   44309.661290      167261.338710   2010.798387      2.653226
# 17      citroen   28430.662338      132246.500000   2012.818182      2.311688
# 18         opel   32634.403727      131133.844720   2013.664596      2.236025
# 19   mitsubishi   23671.007519      190687.593985   2010.233083      2.819549
# 20       nissan   34937.635135      133741.885135   2012.554054      2.202703
# 21         fiat   24007.365385      128088.339744   2012.903846      2.480769
# 22        volvo   58416.267327      145987.465347   2010.831683      2.544554
# 23   alphaRomeo   62201.773810      126203.690476   2012.726190      3.023810
# 24     daihatsu   11232.943182      194057.261364   2006.965909      3.318182
# 25         mini   98722.195122       84396.426829   2014.170732      2.682927
#
#     Avarege engine capcity
# 0              1342.072650
# 1              1505.627685
# 2              1355.901575
# 3              1411.840304
# 4              2251.610119
# 5              1592.748954
# 6              1942.148976
# 7              1513.151822
# 8              1896.522013
# 9              1717.520737
# 10             1408.225610
# 11             2103.155738
# 12             1438.006173
# 13             1446.727848
# 14             1851.192308
# 15             1924.012821
# 16             1911.725806
# 17             1480.623377
# 18             1444.857143
# 19             1655.609023
# 20             1530.648649
# 21             1307.839744
# 22             2132.435644
# 23             1650.023810
# 24             1296.670455
# 25             1585.304878

# %% [markdown]
# # Avarege car features by manufacturers
#
# In this section we use the average dataframe we created in the cleaning part to show which car is better for you.

# %%
names_manufacturers = df_avarege['Manufacturer']

# %%
fig = plt.figure(figsize = (20,15))
ax = fig.add_axes([0,0,1,1])
xdata = names_manufacturers
ydata = df_avarege['Avarege price']
ax.bar(xdata,ydata)
ax.set_ylim(min(ydata)-5000, max(ydata)+5000)
plt.xlabel("Manufacturers")
plt.ylabel('Prices')
plt.title('Avarege price')
plt.show()

# %%
fig = plt.figure(figsize = (20,15))
ax = fig.add_axes([0,0,1,1])
xdata = names_manufacturers
ydata = df_avarege['Avarege kilometer']
ax.bar(xdata,ydata)
ax.set_ylim(min(ydata)-5000, max(ydata)+5000)
plt.xlabel("Manufacturers")
plt.ylabel('Kilometer')
plt.title('Avarege kilometer')
plt.show()

# %%
fig = plt.figure(figsize = (20,15))
ax = fig.add_axes([0,0,1,1])
xdata = names_manufacturers
ydata = df_avarege['Avarege year']
ax.bar(xdata,ydata)
ax.set_ylim(min(ydata)-1, max(ydata)+1)
plt.xlabel("Manufacturers")
plt.ylabel('Prices')
plt.title('Avarege year')
plt.show()

# %%
fig = plt.figure(figsize = (20,15))
ax = fig.add_axes([0,0,1,1])
xdata = names_manufacturers
ydata = df_avarege['Avarege hand']
ax.bar(xdata,ydata)
ax.set_ylim(min(ydata)-0.5, max(ydata)+0.5)
plt.xlabel("Manufacturers")
plt.ylabel('Hand')
plt.title('Avarege hand')
plt.show()

# %%
fig = plt.figure(figsize = (20,15))
ax = fig.add_axes([0,0,1,1])
xdata = names_manufacturers
ydata = df_avarege['Avarege engine capcity']
ax.bar(xdata,ydata)
ax.set_ylim(min(ydata)-100, max(ydata)+100)
plt.xlabel("Manufacturers")
plt.ylabel('engine capcity')
plt.title('Avarege engine capcity')
plt.show()

# %% [markdown]
# # Pie of Avarege years and hands of cars

# %%
def extract_col_to_label(col):
    new_dict = dict()
    for val in df_avarege[col]:
        if round(val) not in new_dict:
            new_dict[round(val)] = 1
        else:
            new_dict[round(val)]= new_dict[round(val)]+1
            
    return new_dict

# %%
year_dict = extract_col_to_label('Avarege year')
pd.options.display.float_format = '{:,.0f}'.format
plt.pie(
    year_dict.values(),
    labels = year_dict.keys(),
    shadow=True,
    autopct='%1.0f%%',
    explode=(0.05, 0.05, 0.05,0.05, 0.05, 0.05, 0.05),
    wedgeprops = {"edgecolor" : "black",
              'linewidth': 1,
              'antialiased': True})

plt.title('Avarege years of cars')
plt.show()

# %% [markdown]
# We can see from the pie chart above that most of the second hand cars are from 2014.

# %%
hand_dict = extract_col_to_label('Avarege hand')
pd.options.display.float_format = '{:,.0f}'.format
plt.pie(
    hand_dict.values(),
    labels = hand_dict.keys(),
    shadow=True,
    autopct='%1.0f%%',
    explode=(0.05, 0.05),
    wedgeprops = {"edgecolor" : "black",
              'linewidth': 1,
              'antialiased': True})

plt.title('Avarege hands of cars')
plt.show()

# %% [markdown]
# We can see from the pie chart above that most of the second hand cars have 3 hands.
